# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine
import config

# %%
#Extract CSV into DataFrame
restaurants_df = pd.read_csv("Data/cleanDb_Aug_31cuisines.csv")
restaurants_df
# Out:
#           CAMIS                    RESTAURANT       BORO BUILDING  \
# 0      50100495       AUX MERVEILLEUX DE FRED  Manhattan       37
# 1      50005479            NEW MING'S KITCHEN     Queens     5615
# 2      50060559           NEW GREAT WALL 1419   Brooklyn     1419
# 3      50077348                     HATFIELDS     Queens     4005
# 4      50015219  MING STAR CHINESE RESTAURANT     Queens     8916
# ...         ...                           ...        ...      ...
# 12085  41217162           KINARAS INDIAN FOOD   Brooklyn      368
# 12086  41411833                 PRET A MANGER  Manhattan        2
# 12087  50095788                   SHAXIAN 888   Brooklyn     6024
# 12088  40369954             VOLARE RESTAURANT  Manhattan      147
# 12089  50091872                      DOMINO'S      Bronx     3869
#
#                     STREET  ZIPCODE       PHONE  \
# 0                 8 AVENUE  10014.0  9174751992
# 1            JUNCTION BLVD  11373.0  7186991625
# 2      GRAVESEND NECK ROAD  11229.0  7183765310
# 3                BELL BLVD  11361.0  7182240690
# 4            NORTHERN BLVD  11372.0  7184466994
# ...                    ...      ...         ...
# 12085        MYRTLE AVENUE  11205.0  7182374008
# 12086          PARK AVENUE  10016.0  6463601630
# 12087             7 AVENUE  11220.0  9293970030
# 12088   WEST FOURTH STREET  10012.0  2127772849
# 12089    WHITE PLAINS ROAD  10467.0  7186534618
#
#                      CUISINE_DESCRIPTION INSPECTION_DATE  \
# 0                                 Bakery      2020-02-07
# 1                                Chinese      2020-02-10
# 2                                Chinese      2020-02-18
# 3                               American      2020-01-25
# 4                                Chinese      2020-02-21
# ...                                  ...             ...
# 12085                Indian Subcontinent      2021-07-19
# 12086  Soups_Salads_Sandwiches_Beverages      2020-02-04
# 12087                            Chinese      2020-01-29
# 12088                            Italian      2020-02-04
# 12089                              Pizza      2021-07-21
#
#                                                 ACTION VIOLATION_CODE  \
# 0      Violations were cited in the following area(s).            08A
# 1      Violations were cited in the following area(s).            04L
# 2      Violations were cited in the following area(s).            06D
# 3      Violations were cited in the following area(s).            04L
# 4      Violations were cited in the following area(s).            10F
# ...                                                ...            ...
# 12085  Violations were cited in the following area(s).            06E
# 12086  Violations were cited in the following area(s).            10F
# 12087  Violations were cited in the following area(s).            10F
# 12088  Violations were cited in the following area(s).            10B
# 12089  Violations were cited in the following area(s).            04A
#
#                                           VIOLATION_DESC  CRITICALFLAG  \
# 0      Facility not vermin proof. Harborage or condit...  Not Critical
# 1      Evidence of mice or live mice present in facil...      Critical
# 2      Food contact surface not properly washed, rins...      Critical
# 3      Evidence of mice or live mice present in facil...      Critical
# 4      Non-food contact surface improperly constructe...  Not Critical
# ...                                                  ...           ...
# 12085  Sanitized equipment or utensil, including in-u...      Critical
# 12086  Non-food contact surface improperly constructe...  Not Critical
# 12087  Non-food contact surface improperly constructe...  Not Critical
# 12088  Plumbing not properly installed or maintained;...  Not Critical
# 12089  Food Protection Certificate not held by superv...      Critical
#
#                                       INSPECTIONTYPE   Latitude  Longitude
# 0      Pre-permit (Operational) / Initial Inspection  40.738265 -74.004027
# 1              Cycle Inspection / Initial Inspection  40.737097 -73.866017
# 2                   Cycle Inspection / Re-inspection  40.594708 -73.956308
# 3              Cycle Inspection / Initial Inspection  40.764143 -73.771252
# 4              Cycle Inspection / Initial Inspection  40.756253 -73.878616
# ...                                              ...        ...        ...
# 12085          Cycle Inspection / Initial Inspection  40.693182 -73.971487
# 12086               Cycle Inspection / Re-inspection  40.746070 -73.982092
# 12087  Pre-permit (Operational) / Initial Inspection  40.636637 -74.011962
# 12088               Cycle Inspection / Re-inspection  40.731475 -74.000476
# 12089          Cycle Inspection / Initial Inspection  40.885262 -73.861884
#
# [12090 rows x 16 columns]

# %%
#Extract CSV into DataFrame
violations_df = pd.read_csv("Data/Violations_4fields.csv")
violations_df
# Out:
#                               RESTAURANT VIOLATION_CODE  \
# 0                   #1 NATURAL JUICE BAR            08A
# 1                   #1 NATURAL JUICE BAR            04N
# 2             #1 SABOR LATINO RESTAURANT            10H
# 3             #1 SABOR LATINO RESTAURANT            04N
# 4             #1 SABOR LATINO RESTAURANT            08A
# ...                                  ...            ...
# 43102                    tutto il giorno            06E
# 43103  victoria VANESSA'S DUMPLING HOUSE            10J
# 43104  victoria VANESSA'S DUMPLING HOUSE            06C
# 43105  victoria VANESSA'S DUMPLING HOUSE            04L
# 43106  victoria VANESSA'S DUMPLING HOUSE            05D
#
#                                           VIOLATION_DESC  CRITICALFLAG
# 0      Facility not vermin proof. Harborage or condit...  Not Critical
# 1      Filth flies or food/refuse/sewage-associated (...      Critical
# 2      Proper sanitization not provided for utensil w...  Not Critical
# 3      Filth flies or food/refuse/sewage-associated (...      Critical
# 4      Facility not vermin proof. Harborage or condit...  Not Critical
# ...                                                  ...           ...
# 43102  Sanitized equipment or utensil, including in-u...      Critical
# 43103                          Hand wash sign not posted  Not Critical
# 43104  Food not protected from potential source of co...      Critical
# 43105  Evidence of mice or live mice present in facil...      Critical
# 43106  Hand washing facility not provided in or near ...      Critical
#
# [43107 rows x 4 columns]

# %%
#Create Database connection
connection_string = f"postgres:{config.password}@localhost:5432/restaurant_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# <ipython-input-10-2d97e9123e98>:2: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   engine.table_names()
# ['restaurants', 'violations']

# %%
#Use pandas to Load  csv converted DataFrames into database
restaurants_df.to_sql(name='restaurants', con=engine, if_exists='append', index=False)

# %%
#confirm data has been added by quering the table
pd.read_sql_query('select * from restaurants', con=engine).head()
# Out:
#       camis                            restaurant      boro building  \
# 0  30075445                         DOUBLE DRAGON     Bronx      182
# 1  30112340  C & J JAMAICAN RESTAURANT AND BAKERY    Queens    24712
# 2  40356483                    KINGSTON BAKE SHOP  Brooklyn      380
# 3  40356731                               DENNY'S  Brooklyn      805
# 4  40357217                         MBJ - E KIOSK    Queens     3110
#
#                 street zipcode       phone        cuisine inspectiondate  \
# 0     EAST  166 STREET   10456  7184102838        Chinese        2/24/20
# 1        S CONDUIT AVE   11422  7187122273      Caribbean        1/15/20
# 2      KINGSTON AVENUE   11225  7184672047  Jewish/Kosher        8/24/21
# 3  PENNSYLVANIA AVENUE   11207  7182720301       American         2/4/20
# 4          THOMSON AVE   11101  7184820176     Coffee/Tea         1/9/20
#
#                                             action violationcode  \
# 0  Violations were cited in the following area(s).           02G
# 1  Violations were cited in the following area(s).           04L
# 2  Violations were cited in the following area(s).           06D
# 3  Violations were cited in the following area(s).           06E
# 4  Violations were cited in the following area(s).           06D
#
#                                        violationdesc  critical  \
# 0  Cold food item held above 41º F (smoked fish a...  Critical
# 1  Evidence of mice or live mice present in facil...  Critical
# 2  Food contact surface not properly washed, rins...  Critical
# 3  Sanitized equipment or utensil, including in-u...  Critical
# 4  Food contact surface not properly washed, rins...  Critical
#
#                                   inspectiontype     latitude     longitude
# 0               Cycle Inspection / Re-inspection   40.8315911  -73.91884171
# 1               Cycle Inspection / Re-inspection  40.66534424   -73.7307376
# 2          Cycle Inspection / Initial Inspection  40.66568735  -73.94255354
# 3          Cycle Inspection / Initial Inspection   40.6578923   -73.8900979
# 4  Pre-permit (Operational) / Initial Inspection  40.74489468  -73.93502177

# %%
#Use pandas to Load  csv converted DataFrames into database
violations_df.to_sql(name='violations', con=engine, if_exists='append', index=False)

# %%
#confirm data has been added by quering the table
pd.read_sql_query('select * from violations', con=engine).head()
# Out:
#                    restaurant violation_code  \
# 0        #1 NATURAL JUICE BAR            08A
# 1        #1 NATURAL JUICE BAR            04N
# 2  #1 SABOR LATINO RESTAURANT            10H
# 3  #1 SABOR LATINO RESTAURANT            04N
# 4  #1 SABOR LATINO RESTAURANT            08A
#
#                                       violation_desc      critical  id
# 0  Facility not vermin proof. Harborage or condit...  Not Critical   1
# 1  Filth flies or food/refuse/sewage-associated (...      Critical   2
# 2  Proper sanitization not provided for utensil w...  Not Critical   3
# 3  Filth flies or food/refuse/sewage-associated (...      Critical   4
# 4  Facility not vermin proof. Harborage or condit...  Not Critical   5
