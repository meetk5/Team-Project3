# %%
import pandas as pd
import requests
import time
import json

# %%
url = "https://data.cityofnewyork.us/resource/43nn-pn8j.json?"

# %%
response = requests.get(url).json()

# %%
print(json.dumps(response, indent=2))
# Out:
# [
#   {
#     "camis": "50086702",
#     "dba": "JUSTINO'S PIZZERIA",
#     "boro": "Manhattan",
#     "building": "64",
#     "street": "FULTON STREET",
#     "zipcode": "10038",
#     "phone": "2124066200",
#     "cuisine_description": "Pizza",
#     "inspection_date": "2019-10-04T00:00:00.000",
#     "action": "Establishment Closed by DOHMH. Violations were cited in the following area(s) and those requiring immediate action were addressed.",
#     "violation_code": "02G",
#     "violation_description": "Cold food item held above 41\u00ba F (smoked fish and reduced oxygen packaged foods above 38 \u00baF) except during necessary preparation.",
#     "critical_flag": "Critical",
#     "score": "50",
#     "record_date": "2021-09-13T06:01:34.000",
#     "inspection_type": "Cycle Inspection / Initial Inspection",
#     "latitude": "40.708761649747",
#     "longitude": "-74.005136275218",
#     "community_board": "101",
#     "council_district": "01",
#     "census_tract": "001502",
# ...

# %%
print(response[999]["dba"])
# Out:
# EL REY
