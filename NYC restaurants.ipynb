# %%
import pandas as pd 
import random
import json
import requests
import csv

# %%
restaurants = pd.read_csv ("DOHMH_NYC_Restaurant_Inspection_Res_Cleaned2.csv",  encoding='latin-1')

restaurants.rename({"\u00c3\u00af\u00c2\u00bb\u00c2\u00bfCAMIS": "CAMIS"}, axis='columns')
# Out:
#        ï»¿CAMIS                                   DBA       BORO BUILDING  \
# 0      30075445                         DOUBLE DRAGON      Bronx      182
# 1      30112340  C & J JAMAICAN RESTAURANT AND BAKERY     Queens    24712
# 2      30112340                    KINGSTON BAKE SHOP   Brooklyn      380
# 3      30112340                               DENNY'S   Brooklyn      805
# 4      30112340                         MBJ - E KIOSK     Queens     3110
# ...         ...                                   ...        ...      ...
# 45509  50114708                          EMOJO BURGER  Manhattan      261
# 45510  50114821                            PATRIZIA'S   Brooklyn       35
# 45511  50114821        CIENEGA LAS TLAYUDAS DE OAXACA     Queens    10432
# 45512  50114821               FARIEDA'S DHAL PURI HUT     Queens    11210
# 45513  50114821                 JENNIFER'S RESTAURANT     Queens   153-41
#
#                     STREET  ZIPCODE       PHONE  \
# ...

# %%
restaurants.to_csv("Restaurant_Grades_Clean.csv", encoding='utf-8')

# %%
csv_file= "Restaurant_Grades_Clean.csv"
json_file = "restaurant_grades.json"

# %%
data = {}
with open(csv_file) as csvfile:
    csvreader=csv.DictReader(csvfile)
    for rows in csvreader:
        id = rows["\u00c3\u00af\u00c2\u00bb\u00c2\u00bfCAMIS"]
        data[id]=rows

# %%
with open(json_file, "w")as jsonfile:
    jsonfile.write(json.dumps(data, indent=4))
